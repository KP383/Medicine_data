# %%
import requests

# %%
# for i in range(1, 987):
url = f'https://www.1mg.com/drugs-all-medicines?page={6}'
data = requests.get(url).text
f = open(f"All Medicine HTML/A/A_{6}.txt", "w")
f.write(data)
# Out:
# 153596

# %%
for i in range(1, 911):
    url = f'https://www.1mg.com/drugs-all-medicines?page={i}&label=c'
    data = requests.get(url).text
    f = open(f"All Medicine HTML/C/C_{i}.txt", "w")
    f.write(data)

# %%
for i in range(1, 413):
    url = f'https://www.1mg.com/drugs-all-medicines?page={i}&label=e'
    data = requests.get(url).text
    f = open(f"All Medicine HTML/E/E_{i}.txt", "w")
    f.write(data)

# %%
for i in range(1, 335):
    url = f'https://www.1mg.com/drugs-all-medicines?page={i}&label=g'
    data = requests.get(url).text
    f = open(f"All Medicine HTML/G/G_{i}.txt", "w")
    f.write(data)

# %%
for i in range(1, 214):
    url = f'https://www.1mg.com/drugs-all-medicines?page={i}&label=i'
    data = requests.get(url).text
    f = open(f"All Medicine HTML/I/I_{i}.txt", "w")
    f.write(data)

# %%
for i in range(1, 181):
    url = f'https://www.1mg.com/drugs-all-medicines?page={i}&label=k'
    data = requests.get(url).text
    f = open(f"All Medicine HTML/K/K_{i}.txt", "w")
    f.write(data)

# %%
for i in range(1, 616):
    url = f'https://www.1mg.com/drugs-all-medicines?page={i}&label=m'
    data = requests.get(url).text
    f = open(f"All Medicine HTML/M/M_{i}.txt", "w")
    f.write(data)

# %%
for i in range(1, 434):
    url = f'https://www.1mg.com/drugs-all-medicines?page={i}&label=o'
    data = requests.get(url).text
    f = open(f"All Medicine HTML/O/O_{i}.txt", "w")
    f.write(data)

# %%
for i in range(1, 45):
    url = f'https://www.1mg.com/drugs-all-medicines?page={i}&label=q'
    data = requests.get(url).text
    f = open(f"All Medicine HTML/Q/Q_{i}.txt", "w")
    f.write(data)

# %%
for i in range(1, 549):
    url = f'https://www.1mg.com/drugs-all-medicines?page={i}&label=s'
    data = requests.get(url).text
    f = open(f"All Medicine HTML/S/S_{i}.txt", "w")
    f.write(data)

# %%
for i in range(1, 103):
    url = f'https://www.1mg.com/drugs-all-medicines?page={i}&label=u'
    data = requests.get(url).text
    f = open(f"All Medicine HTML/U/U_{i}.txt", "w")
    f.write(data)

# %%
for i in range(1, 81):
    url = f'https://www.1mg.com/drugs-all-medicines?page={i}&label=w'
    data = requests.get(url).text
    f = open(f"All Medicine HTML/W/W_{i}.txt", "w")
    f.write(data)

# %%
for i in range(1, 24):
    url = f'https://www.1mg.com/drugs-all-medicines?page={i}&label=y'
    data = requests.get(url).text
    f = open(f"All Medicine HTML/Y/Y_{i}.txt", "w")
    f.write(data)

# %%
for i in range(1, 289):
    url = f'https://www.1mg.com/drugs-all-medicines?page={i}&label=v'
    data = requests.get(url).text
    f = open(f"All Medicine HTML/V/V_{i}.txt", "w")
    f.write(data)

# %%
for i in range(1, 562):
    url = f'https://www.1mg.com/drugs-all-medicines?page={i}&label=t'
    data = requests.get(url).text
    f = open(f"All Medicine HTML/T/T_{i}.txt", "w")
    f.write(data)

# %%
import requests
url = f'https://www.cricbuzz.com/cricket-match/live-scores'
data = requests.get(url).text
data
# Out:
# '\r\n\r\n<!DOCTYPE html><html lang="en" itemscope itemtype="http://schema.org/WebPage"><head><meta charset="utf-8"><script>var is_mobile = /symbian|tizen|midp|uc(web|browser)|MSIE (5.0|6.0|7.0|8.0)|tablet/i.test(navigator.userAgent);\tif(is_mobile && window.location.hostname != "www1.cricbuzz.com") window.location.hostname = "m.cricbuzz.com";</script><style>body{background:#E3E6E3; font-family: helvetica,"Segoe UI",Arial,sans-serif;color:#222;font-size:14px; line-height: 1.5; margin:0;}\tbody, .cb-comm-pg, .cb-hm-mid {min-height:1000px}\t.container{width:980px;margin:0 auto;}\t.page{max-width: 980px;margin: 0 auto;position: relative;}\t.cb-col-8 {width:8%;}\t.cb-col-10 {width:10%;}\t.cb-col-14 {width:14%;}\t.cb-col-16 {width:16%;}\t.cb-col-20 {width:20%;}\t.cb-col-25 {width:25%;}\t.cb-col-27 {width:27%;}\t.cb-col-30 {width:30%;}\t.cb-col-33 {width:33%;}\t.cb-col-40 {width:40%;}\t.cb-col-46 {width:46%;}\t.cb-col-47 {width:47%;}\t.cb-col-50 {width:50%;}\t.cb-col-60 {width:60%;}\t.cb-co
# ...
